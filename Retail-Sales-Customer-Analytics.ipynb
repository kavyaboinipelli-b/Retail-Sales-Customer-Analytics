# %%
print("Hello Kavyasri")
# Out:
# Hello Kavyasri

# %%
name = "Kavyasri"
age = 22

print(name)
print(age)
# Out:
# Kavyasri
# 22

# %%
city = "Jagtial"
salary = 600000

print(city)
print(salary)
# Out:
# Jagtial
# 600000

# %%
print(type(city))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>

# %%
skills = ["SQL", "Power BI", "Python"]

print(skills)
# Out:
# ['SQL', 'Power BI', 'Python']

# %%
print(skills[0])
print(skills[1])
print(skills[2])
# Out:
# SQL
# Power BI
# Python

# %%
sales = [1000, 2000, 3000, 4000]

print(sum(sales))
print(max(sales))
print(min(sales))
# Out:
# 10000
# 4000
# 1000

# %%
student = {
    "name": "Kavyasri",
    "age": 22,
    "skill": "Power BI"
}

print(student)
# Out:
# {'name': 'Kavyasri', 'age': 22, 'skill': 'Power BI'}

# %%
print(student["name"])
print(student["age"])
print(student["skill"])
# Out:
# Kavyasri
# 22
# Power BI

# %%
skills = ["SQL", "Power BI", "Python"]

for skill in skills:
    print(skill)
# Out:
# SQL
# Power BI
# Python

# %%
def greet(name):
    print("Hello", name)

greet("Kavyasri")
# Out:
# Hello Kavyasri

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas as pd

data = {
    "Name": ["Kavyasri", "John", "Priya"],
    "Age": [22, 25, 24],
    "Salary": [600000, 500000, 700000]
}

df = pd.DataFrame(data)

df
# Out:
#        Name  Age  Salary
# 0  Kavyasri   22  600000
# 1      John   25  500000
# 2     Priya   24  700000

# %%
df.head()
# Out:
#        Name  Age  Salary
# 0  Kavyasri   22  600000
# 1      John   25  500000
# 2     Priya   24  700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#              Age    Salary
# count   3.000000       3.0
# mean   23.666667  600000.0
# std     1.527525  100000.0
# min    22.000000  500000.0
# 25%    23.000000  550000.0
# 50%    24.000000  600000.0
# 75%    24.500000  650000.0
# max    25.000000  700000.0

# %%
df["Bonus"] = df["Salary"] * 0.10

df
# Out:
#        Name  Age  Salary    Bonus
# 0  Kavyasri   22  600000  60000.0
# 1      John   25  500000  50000.0
# 2     Priya   24  700000  70000.0

# %%
df.sort_values("Salary", ascending=False)
# Out:
#        Name  Age  Salary    Bonus
# 2     Priya   24  700000  70000.0
# 0  Kavyasri   22  600000  60000.0
# 1      John   25  500000  50000.0

# %%
df[df["Salary"] > 550000]
# Out:
#        Name  Age  Salary    Bonus
# 0  Kavyasri   22  600000  60000.0
# 2     Priya   24  700000  70000.0

# %%
df[df["Age"] < 24]
# Out:
#        Name  Age  Salary    Bonus
# 0  Kavyasri   22  600000  60000.0

# %%
df.groupby("Age")["Salary"].mean()
# Out:
# Age
# 22    600000.0
# 24    700000.0
# 25    500000.0
# Name: Salary, dtype: float64

# %%
df.groupby("Age")["Bonus"].sum()
# Out:
# Age
# 22    60000.0
# 24    70000.0
# 25    50000.0
# Name: Bonus, dtype: float64

# %%
data = {
    "Name": ["Kavyasri", "John", "Priya", "Rahul", "Anjali"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [600000, 500000, 700000, 550000, 650000]
}

df2 = pd.DataFrame(data)

df2
# Out:
#        Name Department  Salary
# 0  Kavyasri         IT  600000
# 1      John         HR  500000
# 2     Priya         IT  700000
# 3     Rahul    Finance  550000
# 4    Anjali         HR  650000

# %%
df2.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    550000.0
# HR         575000.0
# IT         650000.0
# Name: Salary, dtype: float64

# %%
df2.to_csv("employees.csv", index=False)

# %%
new_df = pd.read_csv("employees.csv")

new_df
# Out:
#        Name Department  Salary
# 0  Kavyasri         IT  600000
# 1      John         HR  500000
# 2     Priya         IT  700000
# 3     Rahul    Finance  550000
# 4    Anjali         HR  650000

# %%
new_df.head()
# Out:
#        Name Department  Salary
# 0  Kavyasri         IT  600000
# 1      John         HR  500000
# 2     Priya         IT  700000
# 3     Rahul    Finance  550000
# 4    Anjali         HR  650000

# %%
employee_data = {
    "Employee": ["Amit", "Priya", "Rahul", "Sneha", "Kiran", "Anjali"],
    "Department": ["IT", "HR", "IT", "Finance", "HR", "IT"],
    "Salary": [70000, 50000, 80000, 65000, 55000, 90000],
    "Experience": [3, 2, 5, 4, 2, 6]
}

emp_df = pd.DataFrame(employee_data)

emp_df
# Out:
#   Employee Department  Salary  Experience
# 0     Amit         IT   70000           3
# 1    Priya         HR   50000           2
# 2    Rahul         IT   80000           5
# 3    Sneha    Finance   65000           4
# 4    Kiran         HR   55000           2
# 5   Anjali         IT   90000           6

# %%
emp_df[emp_df["Salary"] > 60000]
# Out:
#   Employee Department  Salary  Experience
# 0     Amit         IT   70000           3
# 2    Rahul         IT   80000           5
# 3    Sneha    Finance   65000           4
# 5   Anjali         IT   90000           6

# %%
emp_df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    65000.0
# HR         52500.0
# IT         80000.0
# Name: Salary, dtype: float64

# %%
emp_df["Bonus"] = emp_df["Salary"] * 0.10

emp_df
# Out:
#   Employee Department  Salary  Experience   Bonus
# 0     Amit         IT   70000           3  7000.0
# 1    Priya         HR   50000           2  5000.0
# 2    Rahul         IT   80000           5  8000.0
# 3    Sneha    Finance   65000           4  6500.0
# 4    Kiran         HR   55000           2  5500.0
# 5   Anjali         IT   90000           6  9000.0

# %%
emp_df.sort_values("Salary", ascending=False)
# Out:
#   Employee Department  Salary  Experience   Bonus
# 5   Anjali         IT   90000           6  9000.0
# 2    Rahul         IT   80000           5  8000.0
# 0     Amit         IT   70000           3  7000.0
# 3    Sneha    Finance   65000           4  6500.0
# 4    Kiran         HR   55000           2  5500.0
# 1    Priya         HR   50000           2  5000.0

# %%
emp_df.sort_values("Salary", ascending=False)
# Out:
#   Employee Department  Salary  Experience   Bonus
# 5   Anjali         IT   90000           6  9000.0
# 2    Rahul         IT   80000           5  8000.0
# 0     Amit         IT   70000           3  7000.0
# 3    Sneha    Finance   65000           4  6500.0
# 4    Kiran         HR   55000           2  5500.0
# 1    Priya         HR   50000           2  5000.0

# %%
emp_df["Salary"].mean()
# Out:
# np.float64(68333.33333333333)

# %%
emp_df["Salary"].max()
# Out:
# 90000

# %%
emp_df["Salary"].min()
# Out:
# 50000

# %%
emp_df["Salary"].sum()
# Out:
# np.int64(410000)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\91701\OneDrive\Desktop\Retail-Sales-Customer-Analytics\Dataset\SampleSuperstore.csv")

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Profit"].sum().sort_values(ascending=False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Florida          89473.7080
# Illinois         80166.1010
# Ohio             78258.1360
# Michigan         76269.6140
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

top_states = df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(10)

top_states.plot(kind="bar")

plt.title("Top 10 States by Sales")
plt.xlabel("State")
plt.ylabel("Sales")

plt.show()

# %%
df.groupby("Category")[["Sales","Profit"]].sum()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df.groupby("Category")[["Sales","Profit"]].sum().plot(kind="bar")
plt.show()

# %%
df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df.groupby("Sub-Category")["Profit"].sum().sort_values()
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
top_profit = df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)

top_profit.plot(kind="bar", figsize=(12,5))

plt.title("Profit by Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Profit")

plt.show()

# %%
df[df["Sub-Category"] == "Tables"]
# Out:
#            Ship Mode      Segment        Country             City       State  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale     Florida
# 10    Standard Class     Consumer  United States      Los Angeles  California
# 24    Standard Class     Consumer  United States             Orem        Utah
# 117   Standard Class     Consumer  United States          Seattle  Washington
# 125   Standard Class     Consumer  United States      Bloomington    Illinois
# ...              ...          ...            ...              ...         ...
# 9857  Standard Class    Corporate  United States          Seattle  Washington
# 9899  Standard Class  Home Office  United States      Springfield        Ohio
# 9937    Second Class    Corporate  United States      Los Angeles  California
# 9955    Second Class    Corporate  United States      Los Angeles  California
# 9980    Second Class     Consumer  United States        Lafayette   Louisiana
#
# ...

# %%
df[df["Sub-Category"] == "Tables"][["Sales","Profit","Discount"]].describe()
# Out:
#              Sales       Profit    Discount
# count   319.000000   319.000000  319.000000
# mean    648.794771   -55.565771    0.261285
# std     615.774655   230.565006    0.169622
# min      24.368000 -1862.312400    0.000000
# 25%     244.006000  -122.829300    0.200000
# 50%     447.840000   -31.372200    0.300000
# 75%     872.170000    33.851700    0.400000
# max    4297.644000   629.010000    0.500000

# %%
print(df.columns)
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
top_cities = df.groupby("City")["Sales"].sum().sort_values(ascending=False).head(10)

top_cities
# Out:
# City
# New York City    256368.1610
# Los Angeles      175851.3410
# Seattle          119540.7420
# San Francisco    112669.0920
# Philadelphia     109077.0130
# Houston           64504.7604
# Chicago           48539.5410
# San Diego         47521.0290
# Jacksonville      44713.1830
# Springfield       43054.3420
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

top_cities.plot(kind="bar", figsize=(10,5))
plt.title("Top 10 Cities by Sales")
plt.ylabel("Sales")
plt.show()

# %%
city_profit = df.groupby("City")["Profit"].sum().sort_values().head(10)

city_profit
# Out:
# City
# Philadelphia   -13837.7674
# Houston        -10153.5485
# San Antonio     -7299.0502
# Lancaster       -7239.0684
# Chicago         -6654.5688
# Burlington      -3622.8772
# Dallas          -2846.5257
# Phoenix         -2790.8832
# Aurora          -2691.7386
# Jacksonville    -2323.8350
# Name: Profit, dtype: float64

# %%
city_profit = df.groupby("City")["Profit"].sum().sort_values().head(10)

city_profit
# Out:
# City
# Philadelphia   -13837.7674
# Houston        -10153.5485
# San Antonio     -7299.0502
# Lancaster       -7239.0684
# Chicago         -6654.5688
# Burlington      -3622.8772
# Dallas          -2846.5257
# Phoenix         -2790.8832
# Aurora          -2691.7386
# Jacksonville    -2323.8350
# Name: Profit, dtype: float64

# %%
city_profit.plot(kind="bar", figsize=(10,5), title="Bottom 10 Cities by Profit")
plt.ylabel("Profit")
plt.show()

# %%
df.groupby("City")[["Discount","Profit"]].mean().sort_values("Profit").head(10)
# Out:
#              Discount      Profit
# City
# Bethlehem    0.380000 -200.619160
# Champaign    0.600000 -182.352000
# Oswego       0.600000 -178.709200
# Round Rock   0.274286 -169.061614
# Lancaster    0.315217 -157.371052
# Clarksville  0.271429 -150.764743
# Medina       0.433333 -149.227178
# Burlington   0.136000 -144.915088
# San Antonio  0.383051 -123.712715
# Yuma         0.450000 -116.497725

# %%
df.groupby("Category")[["Sales","Profit"]].sum()
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df.groupby("Category")[["Sales","Profit"]].sum().plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Sales and Profit by Category")
plt.show()

# %%
furniture = df[df["Category"] == "Furniture"]

furniture.groupby("Sub-Category")["Profit"].sum().sort_values()
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Furnishings    13059.1436
# Chairs         26590.1663
# Name: Profit, dtype: float64
